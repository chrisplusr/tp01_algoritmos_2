# %%
from graham_scan import graham_scan
from point import Point
import separability
import matplotlib.pyplot as plt

# %%
plt.ion()

# %%
P1 = [(-0.0416362796235,2.0778654613117),
(2.9990350955684,3.8597407039375),
(2.4995784815943,3.7511631791605),
(-0.1931441328748,5.7272741301016),
(-2.2778326085929,3.7945941890713),
(-1.7792230836344,2.2270202473948),
(-1.5567055008463,2.3441347646517),
(-1.6722033989374,2.9943967149038),
(-1.8601463611155,3.7606257145533),
(0.6553979018846,3.5582256014384)]

P2 = [(-4.2557525101923,-0.2573772649794),
(-2.4918882285364,0.2838083668922),
(-2.7324151760349,1.7871017887581),
(-4.6365868437316,2.2080239468805),
(-5.5385628968511,1.9875409116735),
(-4.5564111945655,0.604510963557),
(-3.9350499135276,1.1456965954287),
(-4.8570698789386,1.3461357183441),
(-5.1176407387287,1.6868822273003),
(-4.4962794576908,1.8672774379242)]

P3 = [(4,0),
(6,1),
(6.99,2.57),
(5,4),
(2,3),
(1.35,0.99)]


P4 = [(1.4675275243176,-0.2507300913821),
(3.2171625600276,1.23526130881),
(2.8336809083651,2.8650583283755),
(1.2038838887996,3.8477300607606),
(-1.0970060211752,3.3204427897247),
(-1.8400017212713,1.474937341099)]

# %%
H1 = separability.get_convex_hull(P1)
H2 = separability.get_convex_hull(P2)
H3 = separability.get_convex_hull(P3)
H4 = separability.get_convex_hull(P4)


print(separability.separability(H1, H2))
print(separability.separability(H1, H3))
print(separability.separability(H1, H4))
print(separability.separability(H2, H3))
print(separability.separability(H2, H4))
print(separability.separability(H3, H4))

H1.append(H1[0])
H2.append(H2[0])
H3.append(H3[0])
H4.append(H4[0])
# Out:
# False
# False
# True
# False
# False
# True

# %%
x, y = [], []
for i in H1:
    x.append(i.x)
    y.append(i.y)
w, z = zip(*P1)

a, b = [], []
for i in H2:
    a.append(i.x)
    b.append(i.y)
c, d = zip(*P2)

plt.plot(x, y)
plt.plot(a, b)
plt.scatter(c, d)
plt.scatter(w, z)

# %%
x, y = [], []
for i in H1:
    x.append(i.x)
    y.append(i.y)
w, z = zip(*P1)

a, b = [], []
for i in H3:
    a.append(i.x)
    b.append(i.y)
c, d = zip(*P3)

plt.plot(x, y)
plt.plot(a, b)
plt.scatter(c, d)
plt.scatter(w, z)

# %%
x, y = [], []
for i in H1:
    x.append(i.x)
    y.append(i.y)
w, z = zip(*P1)

a, b = [], []
for i in H4:
    a.append(i.x)
    b.append(i.y)
c, d = zip(*P4)

plt.plot(x, y)
plt.plot(a, b)
plt.scatter(c, d)
plt.scatter(w, z)

# %%
x, y = [], []
for i in H2:
    x.append(i.x)
    y.append(i.y)
w, z = zip(*P2)

a, b = [], []
for i in H3:
    a.append(i.x)
    b.append(i.y)
c, d = zip(*P3)

plt.plot(x, y)
plt.plot(a, b)
plt.scatter(c, d)
plt.scatter(w, z)

# %%
x, y = [], []
for i in H2:
    x.append(i.x)
    y.append(i.y)
w, z = zip(*P2)

a, b = [], []
for i in H4:
    a.append(i.x)
    b.append(i.y)
c, d = zip(*P4)

plt.plot(x, y)
plt.plot(a, b)
plt.scatter(c, d)
plt.scatter(w, z)

# %%
x, y = [], []
for i in H3:
    x.append(i.x)
    y.append(i.y)
w, z = zip(*P3)

a, b = [], []
for i in H4:
    a.append(i.x)
    b.append(i.y)
c, d = zip(*P4)

plt.plot(x, y)
plt.plot(a, b)
plt.scatter(c, d)
plt.scatter(w, z)
